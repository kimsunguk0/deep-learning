# %% [markdown]
# 1. 데이터 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DSA_features.csv')
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
df.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  LL_ymag_std  \
# 0     1.083150      1.1832     0.99744    0.002208  ...     0.000792
# 1     1.140865      1.2129     1.05810    0.000784  ...     0.000860
# 2     1.140962      1.2128     1.07960    0.000508  ...     0.000762
# 3     1.165260      1.3170     1.07870    0.002173  ...     0.000735
# 4     1.187504      1.2574     1.09450    0.000662  ...     0.000824
#
#    LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min   LL_zmag_var  \
# 0      0.177075     -0.057119    -0.054963    -0.059241  6.778722e-07
# 1     -0.286918     -0.057268    -0.054945    -0.059589  7.032302e-07
# 2     -0.134430     -0.057068    -0.054711    -0.059065  6.268222e-07
# 3      0.021485     -0.056422    -0.053670    -0.058310  8.011245e-07
# 4     -0.148229     -0.055801    -0.053313    -0.057815  6.853423e-07
#
#    LL_zmag_std  LL_zmag_skew  activity  people
# 0     0.000823      0.036729   sitting      p1
# 1     0.000839      0.347471   sitting      p1
# 2     0.000792      0.045579   sitting      p1
# 3     0.000895      0.240690   sitting      p1
# 4     0.000828      0.258429   sitting      p1
#
# [5 rows x 272 columns]

# %%
# 결측치 확인

df.isnull().values.any()
# Out:
# False

# %% [markdown]
# 2. 필요한 데이터만 추출하기
#
# Normal - lyingBack,lyingRigh
#
# Abnormal - sitting 으로

# %%
print(df['activity'].unique())
# Out:
# ['sitting' 'standing' 'lyingBack' 'lyingRigh' 'ascendingStairs'
#  'decendingStairs' 'standingInElevatorStill' 'movingInElevator'
#  'walkingLot' 'walkingTreadmillFlat' 'walkingTreadmillIncline'
#  'runningTreadmill' 'stepper' 'crossTrainer' 'cyclingHorizontal'
#  'cyclingVertical' 'rowing' 'jumping' 'basketBall']

# %%
# activity 열에서 'lyingBack', 'lyingRigh', 'sitting' 만 추출하기
df = df[df['activity'].isin(['lyingBack', 'lyingRigh', 'sitting'])]
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 1915     2.620502      2.6592      2.5891    0.000199    0.014113
# 1916     2.613423      2.6572      2.5815    0.000207    0.014387
# 1917     2.614750      2.6576      2.5654    0.000257    0.016018
# 1918     2.620167      2.6589      2.5781    0.000216    0.014691
# 1919     2.615565      2.6789      2.5734    0.000310    0.017610
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 1915     0.148452    -9.392025     -9.3424    -9.42070    0.000242  ...
# 1916     0.368746    -9.398851     -9.3657    -9.43560    0.000156  ...
# 1917    -0.007991    -9.397350     -9.3628    -9.43130    0.000214  ...
# 1918    -0.114904    -9.397014     -9.3649    -9.45390    0.000257  ...
# 1919     0.608394    -9.398614     -9.3661    -9.42790    0.000167  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 1915     0.009589      0.401254     -0.410987    -0.382210    -0.446050
# 1916     0.008588      0.147180     -0.411248    -0.365810    -0.436760
# 1917     0.005814      0.032341     -0.409787    -0.379260    -0.434310
# 1918     0.009510      0.409508     -0.409101    -0.360740    -0.440870
# 1919     0.009874      0.413339     -0.410440    -0.385880    -0.438410
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew   activity  people
# 0     6.778722e-07     0.000823      0.036729    sitting      p1
# 1     7.032302e-07     0.000839      0.347471    sitting      p1
# 2     6.268222e-07     0.000792      0.045579    sitting      p1
# 3     8.011245e-07     0.000895      0.240690    sitting      p1
# 4     6.853423e-07     0.000828      0.258429    sitting      p1
# ...            ...          ...           ...        ...     ...
# 1915  9.935077e-05     0.009967     -0.597598  lyingRigh      p8
# 1916  8.659481e-05     0.009306      1.021454  lyingRigh      p8
# 1917  7.258946e-05     0.008520      0.431012  lyingRigh      p8
# 1918  1.127801e-04     0.010620      1.368666  lyingRigh      p8
# 1919  7.216993e-05     0.008495      0.054973  lyingRigh      p8
#
# [1440 rows x 272 columns]

# %%
# 제대로 원하는 값들이 추출되었는지 확인하는 과정
df['activity'].unique(), df.shape, df['activity'].value_counts()
# Out:
# (array(['sitting', 'lyingBack', 'lyingRigh'], dtype=object),
#  (1440, 272),
#  activity
#  sitting      480
#  lyingBack    480
#  lyingRigh    480
#  Name: count, dtype: int64)

# %% [markdown]
# 3. activity 열 전처리 하기

# %% [markdown]
# activity 값이 수치형 데이터가 아니므로 sitting 등 문자열이 아닌 정상 데이터를 0으로 비정상 데이터를 1로 바꿔준다.

# %%
# 'activity' 열 전처리: lyingBack, lyingRigh -> 정상 (0), sitting -> 비정상 (1)
df['activity'] = df['activity'].replace({'lyingBack': 0, 'lyingRigh': 0, 'sitting': 1})
df
# Out:
# <ipython-input-146-37417d3b719c>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['activity'] = df['activity'].replace({'lyingBack': 0, 'lyingRigh': 0, 'sitting': 1})
# <ipython-input-146-37417d3b719c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['activity'] = df['activity'].replace({'lyingBack': 0, 'lyingRigh': 0, 'sitting': 1})
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 1915     2.620502      2.6592      2.5891    0.000199    0.014113
# 1916     2.613423      2.6572      2.5815    0.000207    0.014387
# 1917     2.614750      2.6576      2.5654    0.000257    0.016018
# 1918     2.620167      2.6589      2.5781    0.000216    0.014691
# 1919     2.615565      2.6789      2.5734    0.000310    0.017610
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 1915     0.148452    -9.392025     -9.3424    -9.42070    0.000242  ...
# 1916     0.368746    -9.398851     -9.3657    -9.43560    0.000156  ...
# 1917    -0.007991    -9.397350     -9.3628    -9.43130    0.000214  ...
# 1918    -0.114904    -9.397014     -9.3649    -9.45390    0.000257  ...
# 1919     0.608394    -9.398614     -9.3661    -9.42790    0.000167  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 1915     0.009589      0.401254     -0.410987    -0.382210    -0.446050
# 1916     0.008588      0.147180     -0.411248    -0.365810    -0.436760
# 1917     0.005814      0.032341     -0.409787    -0.379260    -0.434310
# 1918     0.009510      0.409508     -0.409101    -0.360740    -0.440870
# 1919     0.009874      0.413339     -0.410440    -0.385880    -0.438410
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity  people
# 0     6.778722e-07     0.000823      0.036729         1      p1
# 1     7.032302e-07     0.000839      0.347471         1      p1
# 2     6.268222e-07     0.000792      0.045579         1      p1
# 3     8.011245e-07     0.000895      0.240690         1      p1
# 4     6.853423e-07     0.000828      0.258429         1      p1
# ...            ...          ...           ...       ...     ...
# 1915  9.935077e-05     0.009967     -0.597598         0      p8
# 1916  8.659481e-05     0.009306      1.021454         0      p8
# 1917  7.258946e-05     0.008520      0.431012         0      p8
# 1918  1.127801e-04     0.010620      1.368666         0      p8
# 1919  7.216993e-05     0.008495      0.054973         0      p8
#
# [1440 rows x 272 columns]

# %%
# 비율 확인
LABELS = ["Normal","Abnormal"]
count_classes = pd.value_counts(df['activity'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("activity class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");
# Out:
# <ipython-input-114-18ebf4ee0311>:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(df['activity'], sort = True)

# %% [markdown]
# 4. 데이터 세트 train,test,valid 분리 및 데이터 정규화하기

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x_train, x_test = train_test_split(df, test_size=0.2,shuffle=True, random_state=42)
x_train, x_valid = train_test_split(x_train, test_size=0.2,shuffle=True, random_state=42)

# 정상 데이터(0)만 사용하여 학습에 활용 (lyingBack, lyingRight)
# values를 통해 넘파이 배열로 바꿔주기
x_train = x_train[x_train.activity == 0]
x_train = x_train.drop(['activity', 'people'], axis=1).values

x_valid = x_valid[x_valid.activity == 0]
x_valid = x_valid.drop(['activity', 'people'], axis=1).values

# 테스트 레이블을 남겨두는 이유는 나중에 정확도를 비교하기 위해서임
y_test = x_test['activity']  # 테스트 데이터에서 활동 라벨만 남기기
x_test = x_test.drop(['activity', 'people'], axis=1).values

x_train.shape, x_valid.shape, x_test.shape, y_test.shape
# Out:
# ((607, 270), (156, 270), (288, 270), (288,))

# %%
# StandardScaler로 데이터 정규화
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_valid = scaler.transform(x_valid)
x_test = scaler.transform(x_test)

x_train.shape, x_valid.shape, x_test.shape
# Out:
# ((607, 270), (156, 270), (288, 270))

# %% [markdown]
# 5. 선형 오토인코더(Linear AutoEncoder) 모델 만들기

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# 기존 오토인코더와 달리 선형 오토인코더는 활성화 함수로 'relu' 등이 필요가 없다.

# %% [markdown]
# 비선형 활성화 함수인 ReLU,sigmoid등은 데이터의 비선형적 특성을 학습하는데 유리하지만,
#
# 선형 오토인코더는 PCA와 같은 선형 변환을 수행하기 때문에 비선형 활성화 함수가 필요없는 것이다.
#
# 대신에 활성화 함수로 linear를 적용한다.

# %%
# 선형 오토인코더 모델
input_dim = x_train.shape[1]
#입력 차원의 1/10인 27을 넣을 수도 있다.
encoding_dim = 27  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)


def linear_autoencoder(input_dim, encoding_dim):

    input_layer = Input(shape=(input_dim,))
    encoded = Dense(encoding_dim, activation='linear')(input_layer)
    encoded = Dense(int(encoding_dim/2), activation='linear')(encoded)
    decoded = Dense(int(encoding_dim/2), activation='linear')(encoded)
    decoded = Dense(input_dim, activation='linear')(decoded)

    # Autoencoder 모델
    autoencoder = Model(inputs=input_layer, outputs=decoded)
    return autoencoder

# 모델 빌드
autoencoder = linear_autoencoder(input_dim, encoding_dim)

autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)          │ (None, 270)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_49 (Dense)                     │ (None, 27)                  │           7,317 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_50 (Dense)                     │ (None, 13)                  │             364 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_51 (Dense)                     │ (None, 13)                  │             182 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_52 (Dense)                     │ (None, 270)                 │           3,780 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,643 (45.48 KB)
#  Trainable params: 11,643 (45.48 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 학습하기

# %%
history = autoencoder.fit(x_train,x_train,epochs=50,batch_size=32,validation_data=(x_valid,x_valid),shuffle=True)
# Out:
# Epoch 1/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1.1003 - val_loss: 0.6832
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0877 - val_loss: 0.6310
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2012 - val_loss: 0.5787
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7363 - val_loss: 0.5379
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0404 - val_loss: 0.5106
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9052 - val_loss: 0.4812
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6469 - val_loss: 0.4584
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5508 - val_loss: 0.4342
# Epoch 9/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5781 - val_loss: 0.4155
# Epoch 10/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4621 - val_loss: 0.3952
# Epoch 11/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5505 - val_loss: 0.3825
# Epoch 12/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4573 - val_loss: 0.3671
# Epoch 13/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4391 - val_loss: 0.3617
# Epoch 14/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4139 - val_loss: 0.3492
# Epoch 15/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4196 - val_loss: 0.3452
# Epoch 16/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4131 - val_loss: 0.3361
# Epoch 17/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5161 - val_loss: 0.3298
# Epoch 18/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5331 - val_loss: 0.3256
# Epoch 19/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4048 - val_loss: 0.3209
# Epoch 20/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3979 - val_loss: 0.3149
# Epoch 21/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3967 - val_loss: 0.3120
# Epoch 22/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3609 - val_loss: 0.3072
# Epoch 23/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4882 - val_loss: 0.3041
# Epoch 24/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3879 - val_loss: 0.2998
# Epoch 25/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3781 - val_loss: 0.2977
# Epoch 26/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3728 - val_loss: 0.2968
# Epoch 27/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4744 - val_loss: 0.3171
# Epoch 28/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5163 - val_loss: 0.3116
# Epoch 29/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3665 - val_loss: 0.2917
# Epoch 30/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3348 - val_loss: 0.2888
# Epoch 31/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3829 - val_loss: 0.2822
# Epoch 32/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3150 - val_loss: 0.2820
# Epoch 33/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3139 - val_loss: 0.2781
# Epoch 34/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3554 - val_loss: 0.2791
# Epoch 35/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3521 - val_loss: 0.2745
# Epoch 36/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3609 - val_loss: 0.2749
# Epoch 37/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3912 - val_loss: 0.2715
# Epoch 38/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3125 - val_loss: 0.2719
# Epoch 39/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3348 - val_loss: 0.2688
# Epoch 40/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3010 - val_loss: 0.2822
# Epoch 41/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3274 - val_loss: 0.2673
# Epoch 42/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3429 - val_loss: 0.2707
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3107 - val_loss: 0.2640
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3169 - val_loss: 0.2655
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3295 - val_loss: 0.2633
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2728 - val_loss: 0.2639
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3507 - val_loss: 0.2636
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3180 - val_loss: 0.2602
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3200 - val_loss: 0.2619
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3196 - val_loss: 0.2605

# %% [markdown]
# 손실값 그래프로 출력

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right');

# %% [markdown]
# 6. 학습한 결과 바탕으로 최종 분석

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨
# 오토인코더를 사용한 이상 탐지에서, 재구성 오류(Reconstruction Error)는 입력 데이터가
# 얼마나 잘 복원되었는지 측정하는 값
# 이를 통해 정상 데이터와 비정상 데이터를 구분할 수 있다.
# 재구성 오류 값은 test-predic 의 제곱의 평균인 MSE 로 나타내어 표기한다.

predictions = autoencoder.predict(x_test)
mse = np.mean(np.power(x_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df = error_df.reset_index(drop = True)

error_df.describe()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#        reconstruction_error  true_class
# count            288.000000  288.000000
# mean               3.276584    0.315972
# std               39.105023    0.465711
# min                0.071770    0.000000
# 25%                0.118518    0.000000
# 50%                0.212279    0.000000
# 75%                0.650268    1.000000
# max              655.307655    1.000000

# %%
error_df.head()
# Out:
#    reconstruction_error  true_class
# 0              0.738369           1
# 1              0.213825           0
# 2              0.461106           0
# 3              1.120254           1
# 4              0.197657           0

# %% [markdown]
# 정상 데이터의  Reconstruction Error 를 분석해보면
#
# 최솟값은 0.07 최댓값은 4.45 이고
#
# 데이터의 분포는 3분위수값을 보면 0.22 값 아래로 데이터의 75%가 분포 해 있음을 알 수 있다.

# %%
error_df_normal = error_df[error_df['true_class'] == 0].reset_index(drop=True)

error_df_normal.describe()
# Out:
#        reconstruction_error  true_class
# count            197.000000       197.0
# mean               0.273667         0.0
# std                0.535028         0.0
# min                0.071770         0.0
# 25%                0.106356         0.0
# 50%                0.144492         0.0
# 75%                0.221193         0.0
# max                4.454498         0.0

# %% [markdown]
# 비정상 데이터의 Reconstruction Error를 분석해보면
#
# 최솟값은 0.34, 최댓값은 655로 분포해 있고
#
# 3분위수 값을 통하여 데이터의 75%가 0.74 값 아래 있음을 알 수 있다.
#
# 따라서 최적의 threshold를 정할 때 정상 데이터 분석과 비교해서 0.3정도면 적당할 것이다.

# %%
error_df_abnormal = error_df[error_df['true_class'] == 1].reset_index(drop=True)

error_df_abnormal.describe()
# Out:
#        reconstruction_error  true_class
# count             91.000000        91.0
# mean               9.777406         1.0
# std               69.378425         0.0
# min                0.343866         1.0
# 25%                0.631409         1.0
# 50%                0.742299         1.0
# 75%                0.957511         1.0
# max              655.307655         1.0

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음,

threshold =0.3

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %% [markdown]
# confusion_matrix, classification_report 를 통해 여러 수치 확인하기.

# %% [markdown]
# Precision (정밀도): 정밀도는 모델이 Positive 클래스로 예측한 샘플 중에서 실제로 Positive인 샘플의 비율
#
# Recall (재현율): 재현율은 실제 Positive 샘플 중에서 모델이 Positive으로 올바르게 예측한 비율
#
# F1-Score: F1-Score는 정밀도와 재현율의 조화 평균. 즉, 정밀도와 재현율의 균형을 고려한 지표로, 두 값이 비슷할 때 높은 값을 가진다.
#
# Accuracy (정확도): 정확도는 전체 샘플 중에서 모델이 올바르게 예측한 샘플의 비율
#
# Macro Avg (매크로 평균): 클래스 간의 비율에 관계없이 단순 평균을 낸 값
#
# Weighted Avg (가중 평균): 클래스 비율에 따라 가중치를 부여한 평균

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d",cmap="Blues");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92       197
#            1       0.75      1.00      0.86        91
#
#     accuracy                           0.90       288
#    macro avg       0.88      0.92      0.89       288
# weighted avg       0.92      0.90      0.90       288
